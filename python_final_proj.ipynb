# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the Datasets
#    ## Customer Loyalty History

# %%
df1=pd.read_csv('Customer Loyalty History.csv')
df1
# Out:
#        Loyalty Number Country          Province        City Postal Code  \
# 0              480934  Canada           Ontario     Toronto     M2Z 4K1
# 1              549612  Canada           Alberta    Edmonton     T3G 6Y6
# 2              429460  Canada  British Columbia   Vancouver     V6E 3D9
# 3              608370  Canada           Ontario     Toronto     P1W 1K4
# 4              530508  Canada            Quebec        Hull     J8Y 3Z5
# ...               ...     ...               ...         ...         ...
# 16732          823768  Canada  British Columbia   Vancouver     V6E 3Z3
# 16733          680886  Canada      Saskatchewan      Regina     S1J 3C5
# 16734          776187  Canada  British Columbia   Vancouver     V5R 1W3
# 16735          906428  Canada             Yukon  Whitehorse     Y2K 6R0
# 16736          652627  Canada          Manitoba    Winnipeg     R2C 0M5
#
#        Gender Education    Salary Marital Status Loyalty Card       CLV  \
# ...

# %% [markdown]
#  # Explore the Data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
# ...

# %%
df1.describe().T
# Out:
#                       count           mean            std        min  \
# Loyalty Number      16737.0  549735.880445  258912.132453  100018.00
# Salary              12499.0   79245.609409   35008.297285  -58486.00
# CLV                 16737.0    7988.896536    6860.982280    1898.01
# Enrollment Year     16737.0    2015.253211       1.979111    2012.00
# Enrollment Month    16737.0       6.669116       3.398958       1.00
# Cancellation Year    2067.0    2016.503145       1.380743    2013.00
# Cancellation Month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# Loyalty Number      326603.00  550434.00  772019.00  999986.00
# Salary               59246.50   73455.00   88517.50  407228.00
# CLV                   3980.84    5780.18    8940.58   83325.38
# Enrollment Year       2014.00    2015.00    2017.00    2018.00
# Enrollment Month         4.00       7.00      10.00      12.00
# ...

# %%
df1.columns
# Out:
# Index(['Loyalty Number', 'Country', 'Province', 'City', 'Postal Code',
#        'Gender', 'Education', 'Salary', 'Marital Status', 'Loyalty Card',
#        'CLV', 'Enrollment Type', 'Enrollment Year', 'Enrollment Month',
#        'Cancellation Year', 'Cancellation Month'],
#       dtype='object')

# %% [markdown]
# # Clean the Data

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# Loyalty Number            0
# Country                   0
# Province                  0
# City                      0
# Postal Code               0
# Gender                    0
# Education                 0
# Salary                 4238
# Marital Status            0
# Loyalty Card              0
# CLV                       0
# Enrollment Type           0
# Enrollment Year           0
# Enrollment Month          0
# Cancellation Year     14670
# Cancellation Month    14670
# dtype: int64

# %%
# its na when Salary== college 'مشتغلش'
df1['Salary'] = df1['Salary'].fillna(0)

# %%
df1.isna().sum()
# Out:
# Loyalty Number            0
# Country                   0
# Province                  0
# City                      0
# Postal Code               0
# Gender                    0
# Education                 0
# Salary                    0
# Marital Status            0
# Loyalty Card              0
# CLV                       0
# Enrollment Type           0
# Enrollment Year           0
# Enrollment Month          0
# Cancellation Year     14670
# Cancellation Month    14670
# dtype: int64

# %% [markdown]
# # add new col

# %% [markdown]
# # Customer Flight Activity

# %%
df2=pd.read_csv('Customer Flight Activity.csv')
df2.head()
# Out:
#    Loyalty Number  Year  Month  Total Flights  Distance  Points Accumulated  \
# 0          100590  2018      6             12     15276             22914.0
# 1          100590  2018      7             12      9168             13752.0
# 2          100590  2018      5              4      6504              9756.0
# 3          100590  2018     10              0         0                 0.0
# 4          100590  2018      2              0         0                 0.0
#
#    Points Redeemed  Dollar Cost Points Redeemed
# 0                0                            0
# 1                0                            0
# 2                0                            0
# 3              512                           92
# 4                0                            0

# %% [markdown]
#  # Explore the Data

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392936 entries, 0 to 392935
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               392936 non-null  int64
#  1   Year                         392936 non-null  int64
#  2   Month                        392936 non-null  int64
#  3   Total Flights                392936 non-null  int64
#  4   Distance                     392936 non-null  int64
#  5   Points Accumulated           392936 non-null  float64
#  6   Points Redeemed              392936 non-null  int64
#  7   Dollar Cost Points Redeemed  392936 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 24.0 MB

# %%
df2.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty Number               392936.0  550527.519034  258604.580187  100018.0
# Year                         392936.0    2017.513661       0.499814    2017.0
# Month                        392936.0       6.513661       3.445428       1.0
# Total Flights                392936.0       1.294888       1.962675       0.0
# Distance                     392936.0    1941.440201    3239.975889       0.0
# Points Accumulated           392936.0    2027.172345    3872.139841       0.0
# Points Redeemed              392936.0      31.304263     126.653775       0.0
# Dollar Cost Points Redeemed  392936.0       5.635661      22.801167       0.0
#
#                                   25%       50%       75%       max
# Loyalty Number               327688.0  551833.0  772194.0  999986.0
# Year                           2017.0    2018.0    2018.0    2018.0
# ...

# %%
df2.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %% [markdown]
# # Clean the Data

# %%
df2.duplicated().sum()
# Out:
# 1922

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.isna().sum()
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %% [markdown]
# # data Transformation

# %%
df=pd.merge(df1,df2, on ='Loyalty Number')
df.head()
# Out:
#    Loyalty Number Country Province     City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 1          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 2          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 3          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 4          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
#
#     Salary Marital Status Loyalty Card  ...  Enrollment Month  \
# 0  83236.0        Married         Star  ...                 2
# 1  83236.0        Married         Star  ...                 2
# 2  83236.0        Married         Star  ...                 2
# 3  83236.0        Married         Star  ...                 2
# 4  83236.0        Married         Star  ...                 2
#
#   Cancellation Year  Cancellation Month  Year  Month  Total Flights  Distance  \
# ...

# %%
df['Customer Status'] = np.where(df['Cancellation Year'].isna(), 'Active', 'Cancelled')
df.head()
# Out:
#    Loyalty Number Country Province     City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 1          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 2          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 3          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 4          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
#
#     Salary Marital Status Loyalty Card  ...  Cancellation Year  \
# 0  83236.0        Married         Star  ...                NaN
# 1  83236.0        Married         Star  ...                NaN
# 2  83236.0        Married         Star  ...                NaN
# 3  83236.0        Married         Star  ...                NaN
# 4  83236.0        Married         Star  ...                NaN
#
#   Cancellation Month  Year  Month  Total Flights  Distance  \
# 0                NaN  2018      7              5     11355
# ...

# %%
a=df[(df['CLV']>=0) & (df['Total Flights']>=0)]
a.head()
# Out:
#    Loyalty Number Country Province     City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 1          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 2          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 3          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
# 4          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
#
#     Salary Marital Status Loyalty Card  ...  Cancellation Year  \
# 0  83236.0        Married         Star  ...                NaN
# 1  83236.0        Married         Star  ...                NaN
# 2  83236.0        Married         Star  ...                NaN
# 3  83236.0        Married         Star  ...                NaN
# 4  83236.0        Married         Star  ...                NaN
#
#   Cancellation Month  Year  Month  Total Flights  Distance  \
# 0                NaN  2018      7              5     11355
# ...

# %%
df.describe().T
# Out:
#                                 count           mean            std  \
# Loyalty Number               391014.0  550376.476648  258621.151837
# Salary                       391014.0   59347.511672   45494.313054
# CLV                          391014.0    7989.066563    6841.218189
# Enrollment Year              391014.0    2015.162171       1.947461
# Enrollment Month             391014.0       6.784261       3.386518
# Cancellation Year             48155.0    2016.457917       1.375969
# Cancellation Month            48155.0       6.848074       3.430531
# Year                         391014.0    2017.514038       0.499804
# Month                        391014.0       6.514971       3.445263
# Total Flights                391014.0       1.301253       1.965387
# Distance                     391014.0    1950.983205    3245.061634
# Points Accumulated           391014.0    2037.136759    3879.029192
# Points Redeemed              391014.0      31.458137     126.945609
# ...

# %% [markdown]
# # Outliers

# %%
sns.boxplot(data=df ,y='Salary')
plt.title('Salary')
plt.show()

# %%
 # Inter Quantile Range

# %%
# calc IQR 
Q3=df['Salary'].quantile(0.75)
Q1=df['Salary'].quantile(0.25)
IQR=Q3-Q1
IQR
# Out:
# 83139.0

# %%
# cal upper outlier
upper_outlier= Q3 + (1.5 * IQR)
upper_outlier
# Out:
# 207847.5

# %%
# cal lower outlier
lower_outlier= Q1 - (1.5 * IQR)
lower_outlier
# Out:
# -124708.5

# %%
# dealing with lower outlier
df = df[df['Salary'] >= 0]

# %%
df.describe().T
# Out:
#                                 count           mean            std  \
# Loyalty Number               390794.0  550422.436174  258620.547054
# Salary                       390794.0   59400.928223   45449.854598
# CLV                          390794.0    7987.980079    6838.517410
# Enrollment Year              390794.0    2015.160573       1.946844
# Enrollment Month             390794.0       6.786363       3.386266
# Cancellation Year             48133.0    2016.457212       1.375888
# Cancellation Month            48133.0       6.846633       3.430387
# Year                         390794.0    2017.513764       0.499811
# Month                        390794.0       6.514698       3.445396
# Total Flights                390794.0       1.299339       1.957286
# Distance                     390794.0    1948.169458    3232.472255
# Points Accumulated           390794.0    2032.415478    3853.642388
# Points Redeemed              390794.0      31.458029     126.940708
# ...

# %%
# dealing with upper outlier
sns.boxplot(data=df,x='Education',y='Salary')
plt.title('Education VS Salary')
plt.show()
# doctores are most salaries so we don't need to remove them

# %% [markdown]
# # corr between cols

# %%
# corr between salary & Customer lifetime value
corr1= df[['Salary','CLV']].corr()
sns.heatmap(corr1, annot=True )
plt.title('Correlation between Salary & Customer Lifetime Value')
# Out:
# Text(0.5, 1.0, 'Correlation between Salary & Customer Lifetime Value')

# %%
corr2= df[['Total Flights','Distance','Points Accumulated','Dollar Cost Points Redeemed']].corr()
sns.heatmap(corr2, annot=True )
plt.title('Correlation between Total Flights & Distance &Points Accumulated')
# Out:
# Text(0.5, 1.0, 'Correlation between Total Flights & Distance &Points Accumulated')

# %%
df.to_csv(r"F:\Python\final.csv")

# %%
corr3= df[['Total Flights','CLV']].corr()
sns.heatmap(corr1, annot=True )
# Out:
# <Axes: >

# %%
corr4= df[['Total Flights','CLV']].corr()
sns.heatmap(corr4, annot=True )
# Out:
# <Axes: >

# %%
a.describe()
# Out:
#        Loyalty Number         Salary            CLV  Enrollment Year  \
# count   390794.000000  390794.000000  390794.000000    390794.000000
# mean    550422.436174   59400.928223    7987.980079      2015.160573
# std     258620.547054   45449.854598    6838.517410         1.946844
# min     100018.000000       0.000000    1898.010000      2012.000000
# 25%     327498.000000       0.000000    3981.780000      2013.000000
# 50%     551828.000000   63908.500000    5771.610000      2015.000000
# 75%     772181.000000   83156.000000    8940.580000      2017.000000
# max     999986.000000  407228.000000   83325.380000      2018.000000
#
#        Enrollment Month  Cancellation Year  Cancellation Month           Year  \
# count     390794.000000       48133.000000        48133.000000  390794.000000
# mean           6.786363        2016.457212            6.846633    2017.513764
# std            3.386266           1.375888            3.430387       0.499811
# ...
